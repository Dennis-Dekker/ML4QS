# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.version
# Out:
# '3.5.2 (default, Nov 12 2018, 13:43:14) \n[GCC 5.4.0 20160609]'

# %%
data = pd.read_csv("merged_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  bvp      time    hr  acc_x  acc_y  acc_z  eda    temp
# 0           0  0.0  0.000000  72.0   -1.0    1.0   63.0  0.0  382.21
# 1           1  0.0  0.015625   NaN    NaN    NaN    NaN  NaN     NaN
# 2           2  0.0  0.031250   NaN   -1.0    1.0   63.0  NaN     NaN
# 3           3  0.0  0.046875   NaN    NaN    NaN    NaN  NaN     NaN
# 4           4  0.0  0.062500   NaN    0.0    1.0   63.0  NaN     NaN

# %%
data_plot= data.iloc[1000:1500,:]
plt.plot(data_plot["time"],data_plot["bvp"],lw=2)
plt.plot(data_plot["time"],data_plot["bvp"],'r+')
plt.savefig(bvp_plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-31fb855dea3b> in <module>
#       2 plt.plot(data_plot["time"],data_plot["bvp"],lw=2)
#       3 plt.plot(data_plot["time"],data_plot["bvp"],'r+')
# ----> 4 plt.savefig()
#
# ~/.local/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     693 def savefig(*args, **kwargs):
#     694     fig = gcf()
# --> 695     res = fig.savefig(*args, **kwargs)
#     696     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     697     return res
#
# TypeError: savefig() missing 1 required positional argument: 'fname'

# %%
data_plot
# Out:
#       Unnamed: 0    bvp       time     hr  acc_x  acc_y  acc_z       eda  \
# 1000        1000  11.14  15.625000    NaN    1.0    1.0   63.0       NaN
# 1001        1001   9.60  15.640625    NaN    NaN    NaN    NaN       NaN
# 1002        1002   8.18  15.656250    NaN    0.0    1.0   63.0       NaN
# 1003        1003   7.03  15.671875    NaN    NaN    NaN    NaN       NaN
# 1004        1004   6.12  15.687500    NaN    0.0    1.0   63.0       NaN
# 1005        1005   5.25  15.703125    NaN    NaN    NaN    NaN       NaN
# 1006        1006   4.15  15.718750    NaN    1.0    1.0   63.0       NaN
# 1007        1007   2.69  15.734375    NaN    NaN    NaN    NaN       NaN
# 1008        1008   0.86  15.750000    NaN    0.0    1.0   63.0  0.321092
# 1009        1009  -1.15  15.765625    NaN    NaN    NaN    NaN       NaN
# 1010        1010  -3.15  15.781250    NaN    1.0    1.0   63.0       NaN
# 1011        1011  -5.02  15.796875    NaN    NaN    NaN    NaN       NaN
# ...
