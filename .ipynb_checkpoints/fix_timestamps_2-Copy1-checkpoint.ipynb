# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/ML4QS_testrun_2")

# %%
data.head()
# Out:
#            time   gFx   gFy   gFz   ax   ay   az    wx    wy    wz        p  \
# 0  13:18:00:074  0.10  0.02  1.01  0.0  0.0  0.0  0.00  0.00   0.0     0.00
# 1  13:18:00:078  0.10  0.02  1.01  0.0  0.0  0.0  0.00  0.00   0.0  1011.99
# 2  13:18:00:106  0.01  0.05  0.95  0.0  0.0  0.0  0.00  0.00   0.0  1011.99
# 3  13:18:00:109  0.01  0.05  0.95  0.0  0.0  0.0  0.00  0.00   0.0  1011.99
# 4  13:18:00:110  0.01  0.05  0.95  0.0  0.0  0.0  1.49  1.45  19.0  1011.99
#
#     Bx   By   Bz  Azimuth   Pitch  Roll Gain  Unnamed: 18
# 0  0.0  0.0  0.0     0.00    0.00  0.00   -∞          NaN
# 1  0.0  0.0  0.0     0.00    0.00  0.00   -∞          NaN
# 2  0.0  0.0  0.0     0.00    0.00  0.00   -∞          NaN
# 3  0.0  0.0  0.0    73.07  174.65 -8.34   -∞          NaN
# 4  0.0  0.0  0.0    73.07  174.65 -8.34   -∞          NaN

# %%
df_raw = data.drop(["Unnamed: 18"], axis=1)
df_raw = df_raw[df_raw.Gain != "-∞"]
timestamps = []
for i in range(0,len(df_raw.index)):
    timestamps.append("2019:06:14 " + df_raw.time.iloc[i])
df_raw.index = timestamps    
# df_raw = df_raw.set_index("time")
# df_raw = df_raw.astype("float64")

# %%
df_raw.head()
# Out:
#                                  time   gFx   gFy   gFz    ax    ay    az  \
# 2019:06:14 13:18:01:045  13:18:01:045  0.12 -0.06  0.91 -0.10 -1.75 -1.13
# 2019:06:14 13:18:01:047  13:18:01:047  0.12 -0.06  0.91  0.28 -1.82  0.23
# 2019:06:14 13:18:01:049  13:18:01:049  0.12 -0.06  0.91  0.28 -1.82  0.23
# 2019:06:14 13:18:01:052  13:18:01:052  0.12 -0.06  0.91  0.28 -1.82  0.23
# 2019:06:14 13:18:01:054  13:18:01:054 -0.09 -0.05  0.65  0.28 -1.82  0.23
#
#                            wx    wy    wz        p     Bx     By     Bz  \
# 2019:06:14 13:18:01:045  6.93  5.08  3.37  1012.14 -68.22  60.84 -34.92
# 2019:06:14 13:18:01:047  6.93  5.08  3.37  1012.14 -68.22  60.84 -34.92
# 2019:06:14 13:18:01:049  6.93  5.08  3.37  1012.14 -68.22  60.84 -34.92
# 2019:06:14 13:18:01:052  5.47  4.85  1.99  1012.14 -68.22  60.84 -34.92
# 2019:06:14 13:18:01:054  5.47  4.85  1.99  1012.14 -68.22  60.84 -34.92
#
#                          Azimuth  Pitch   Roll   Gain
# ...

# %%
df_raw.index = pd.to_datetime(df_raw.index, format="%Y:%m:%d %H:%M:%S:%f")

# %%
df_raw.head()
# Out:
#                                  time   gFx   gFy   gFz    ax    ay    az  \
# 2019-06-14 13:18:01.045  13:18:01:045  0.12 -0.06  0.91 -0.10 -1.75 -1.13
# 2019-06-14 13:18:01.047  13:18:01:047  0.12 -0.06  0.91  0.28 -1.82  0.23
# 2019-06-14 13:18:01.049  13:18:01:049  0.12 -0.06  0.91  0.28 -1.82  0.23
# 2019-06-14 13:18:01.052  13:18:01:052  0.12 -0.06  0.91  0.28 -1.82  0.23
# 2019-06-14 13:18:01.054  13:18:01:054 -0.09 -0.05  0.65  0.28 -1.82  0.23
#
#                            wx    wy    wz        p     Bx     By     Bz  \
# 2019-06-14 13:18:01.045  6.93  5.08  3.37  1012.14 -68.22  60.84 -34.92
# 2019-06-14 13:18:01.047  6.93  5.08  3.37  1012.14 -68.22  60.84 -34.92
# 2019-06-14 13:18:01.049  6.93  5.08  3.37  1012.14 -68.22  60.84 -34.92
# 2019-06-14 13:18:01.052  5.47  4.85  1.99  1012.14 -68.22  60.84 -34.92
# 2019-06-14 13:18:01.054  5.47  4.85  1.99  1012.14 -68.22  60.84 -34.92
#
#                          Azimuth  Pitch   Roll   Gain
# ...

# %%
timestamps = []
for i in range(0, len(df_raw.index)):
    timestamps.append('%.3f' % (float(df_raw.index[i].to_datetime64().item())/1000000000))
df_raw.index = timestamps

# %%
df_raw.head()
# Out:
#                         time   gFx   gFy   gFz    ax    ay    az    wx    wy  \
# 1560518281.045  13:18:01:045  0.12 -0.06  0.91 -0.10 -1.75 -1.13  6.93  5.08
# 1560518281.047  13:18:01:047  0.12 -0.06  0.91  0.28 -1.82  0.23  6.93  5.08
# 1560518281.049  13:18:01:049  0.12 -0.06  0.91  0.28 -1.82  0.23  6.93  5.08
# 1560518281.052  13:18:01:052  0.12 -0.06  0.91  0.28 -1.82  0.23  5.47  4.85
# 1560518281.054  13:18:01:054 -0.09 -0.05  0.65  0.28 -1.82  0.23  5.47  4.85
#
#                   wz        p     Bx     By     Bz  Azimuth  Pitch   Roll  \
# 1560518281.045  3.37  1012.14 -68.22  60.84 -34.92   114.34  35.24 -45.96
# 1560518281.047  3.37  1012.14 -68.22  60.84 -34.92   114.34  35.24 -45.96
# 1560518281.049  3.37  1012.14 -68.22  60.84 -34.92   118.84  33.59 -31.77
# 1560518281.052  1.99  1012.14 -68.22  60.84 -34.92   118.84  33.59 -31.77
# 1560518281.054  1.99  1012.14 -68.22  60.84 -34.92   118.84  33.59 -31.77
#
#                  Gain
# 1560518281.045  69.73
# ...

# %%
df_raw.index[0]
# Out:
# Timestamp('2019-06-14 13:18:01.045000')

# %%
'%.3f' % (float(df_raw.index[i].to_datetime64().item())/1000000000)
# Out:
# '1560519181.735'

# %%
labels = pd.read_csv("data/Interval2.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-84-b109472f60eb> in <module>()
# ----> 1 labels = pd.read_csv("data/Interval2.csv")
#
# ...
