# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./intermediate_datafiles/processed_data.csv')

# %%
data_ch5 = pd.read_csv('./intermediate_datafiles/chapter5_result.csv')
data.head()
# Out:
#    Unnamed: 0   gFx       gFy       gFz   ax   ay   az            wx  \
# 0        0.00 -0.01 -0.010000  1.019178  0.0  0.0  0.0  4.752667e-20
# 1        0.25 -0.01 -0.009041  1.020000  0.0  0.0  0.0  2.739726e-03
# 2        0.50 -0.01 -0.010000  1.019333  0.0  0.0  0.0  5.200000e-03
# 3        0.75 -0.01 -0.010000  1.017671  0.0  0.0  0.0  2.739726e-03
# 4        1.00 -0.01 -0.010000  1.020000  0.0  0.0  0.0  0.000000e+00
#
#          wy        wz             ...              Azimuth  Pitch  Roll  \
# 0  0.003425  0.155616             ...               183.23   0.44 -0.62
# 1  0.004795  0.159589             ...               183.23   0.44 -0.62
# 2  0.000133  0.157200             ...               183.23   0.44 -0.62
# 3  0.004795  0.151233             ...               183.23   0.44 -0.62
# 4  0.003333  0.157222             ...               183.23   0.44 -0.62
#
#         Gain  label_baseline  label_jump  label_run  label_stand  label_walk  \
# ...

# %%
data["timestamp"] = 0

# %%
for i in range(0,len(data.index)):
    data["timestamp"][i] = pd.to_datetime("6/5/2019 12:06:00") + pd.to_timedelta(data["Unnamed: 0"][i], unit = "s")
# Out:
# /home/martin/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data = data.drop("Unnamed: 0", axis = 1)

# %%
data = data.set_index("timestamp")
data.head()
# Out:
#                           gFx       gFy       gFz   ax   ay   az  \
# timestamp
# 2019-06-05 12:06:00.000 -0.01 -0.010000  1.019178  0.0  0.0  0.0
# 2019-06-05 12:06:00.250 -0.01 -0.009041  1.020000  0.0  0.0  0.0
# 2019-06-05 12:06:00.500 -0.01 -0.010000  1.019333  0.0  0.0  0.0
# 2019-06-05 12:06:00.750 -0.01 -0.010000  1.017671  0.0  0.0  0.0
# 2019-06-05 12:06:01.000 -0.01 -0.010000  1.020000  0.0  0.0  0.0
#
#                                    wx        wy        wz            p  \
# timestamp
# 2019-06-05 12:06:00.000  4.752667e-20  0.003425  0.155616  1008.600548
# 2019-06-05 12:06:00.250  2.739726e-03  0.004795  0.159589  1008.600000
# 2019-06-05 12:06:00.500  5.200000e-03  0.000133  0.157200  1008.603867
# 2019-06-05 12:06:00.750  2.739726e-03  0.004795  0.151233  1008.599726
# 2019-06-05 12:06:01.000  0.000000e+00  0.003333  0.157222  1008.613889
#
#                             ...             Bz  Azimuth  Pitch  Roll  \
# timestamp                   ...
# ...

# %%
data.to_csv("intermediate_datafiles/Data_processed_timestamps.csv")
